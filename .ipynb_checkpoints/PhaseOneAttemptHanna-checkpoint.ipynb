# %%
library(tidyverse)
library(tidymodels)
players <- read_csv("players.csv") |>
                select(played_hours, age) |>
                filter(played_hours > 0)


players_split <- initial_split(players, prop = 0.75, strata = played_hours)
players_train <- training(players_split)
players_test <- testing(players_split)


# Create workflow of the KNN-Regression.
players_spec <- nearest_neighbor(weight_func = "rectangular", neighbors = tune()) |>
                    set_engine("kknn") |>
                    set_mode("regression")

players_recipe <- recipe(played_hours ~ age, data = players) |>
                        step_scale(all_predictors()) |>
                        step_center(all_predictors())

players_workflow <- workflow() |>
                        add_recipe(players_recipe) |>
                        add_model(players_spec)
# Out:
# Rows: 196 Columns: 9
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (4): experience, hashedEmail, name, gender
# dbl (2): played_hours, age
# lgl (3): subscribe, individualId, organizationName
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
# Find which K value works best
players_vfold <- vfold_cv(players_train, v = 5, strata = played_hours)

gridvals <- tibble(neighbors = seq(from = 1, to = 50, by = 1))

players_results <- players_workflow |>
                        tune_grid(resamples = players_vfold, grid = gridvals) |>
                        collect_metrics() |>
                        filter(.metric == "rmse")
players_results

players_results_plot <- players_results |>
                            ggplot(aes(x = neighbors, y = mean)) +
                                    geom_line() +
                                    geom_point() +
                                    labs(x = "# Neighbors", y = "RMSE Mean Value") +
                                    ggtitle("Number Neighbors vs. RMSE Mean")
players_results_plot
# Out:
#    neighbors .metric .estimator mean     n std_err   .config
# 1   1        rmse    standard   37.47180 5 10.638107 Preprocessor1_Model01
# 2   2        rmse    standard   36.29742 5  9.018901 Preprocessor1_Model02
# 3   3        rmse    standard   29.20131 5 10.343149 Preprocessor1_Model03
# 4   4        rmse    standard   27.36728 5 10.251973 Preprocessor1_Model04
# 5   5        rmse    standard   27.31487 5 10.252415 Preprocessor1_Model05
# 6   6        rmse    standard   26.37001 5 10.530563 Preprocessor1_Model06
# 7   7        rmse    standard   25.23172 5 10.818464 Preprocessor1_Model07
# 8   8        rmse    standard   24.42974 5 11.026707 Preprocessor1_Model08
# 9   9        rmse    standard   24.35341 5 11.006505 Preprocessor1_Model09
# 10 10        rmse    standard   23.81490 5 11.139024 Preprocessor1_Model10
# 11 11        rmse    standard   23.62351 5 11.213429 Preprocessor1_Model11
# 12 12        rmse    standard   23.25023 5 11.310753 Preprocessor1_Model12
# 13 13        rmse    standard   23.82663 5 11.141134 Preprocessor1_Model13
# 14 14        rmse    standard   23.48514 5 11.225745 Preprocessor1_Model14
# 15 15        rmse    standard   23.31886 5 11.271245 Preprocessor1_Model15
# 16 16        rmse    standard   23.06467 5 11.341036 Preprocessor1_Model16
# 17 17        rmse    standard   23.38934 5 11.174392 Preprocessor1_Model17
# 18 18        rmse    standard   23.18402 5 11.221393 Preprocessor1_Model18
# 19 19        rmse    standard   23.03096 5 11.170326 Preprocessor1_Model19
# 20 20        rmse    standard   22.87427 5 11.221645 Preprocessor1_Model20
# 21 21        rmse    standard   22.82208 5 11.319410 Preprocessor1_Model21
# 22 22        rmse    standard   22.90262 5 11.305507 Preprocessor1_Model22
# 23 23        rmse    standard   22.98813 5 11.204112 Preprocessor1_Model23
# 24 24        rmse    standard   22.30877 5 11.384002 Preprocessor1_Model24
# 25 25        rmse    standard   22.50206 5 11.326141 Preprocessor1_Model25
# 26 26        rmse    standard   22.66940 5 11.282619 Preprocessor1_Model26
# 27 27        rmse    standard   22.65009 5 11.294171 Preprocessor1_Model27
# 28 28        rmse    standard   22.66809 5 11.306446 Preprocessor1_Model28
# 29 29        rmse    standard   22.66129 5 11.311510 Preprocessor1_Model29
# 30 30        rmse    standard   22.54348 5 11.325777 Preprocessor1_Model30
# 31 31        rmse    standard   22.58127 5 11.321579 Preprocessor1_Model31
# 32 32        rmse    standard   22.50956 5 11.344753 Preprocessor1_Model32
# 33 33        rmse    standard   23.08655 5 11.181764 Preprocessor1_Model33
# 34 34        rmse    standard   23.40995 5 11.037463 Preprocessor1_Model34
# 35 35        rmse    standard   23.34048 5 11.053924 Preprocessor1_Model35
# 36 36        rmse    standard   23.00178 5 11.152110 Preprocessor1_Model36
# 37 37        rmse    standard   23.11230 5 11.131231 Preprocessor1_Model37
# 38 38        rmse    standard   23.07889 5 11.144706 Preprocessor1_Model38
# 39 39        rmse    standard   22.98226 5 11.172942 Preprocessor1_Model39
# 40 40        rmse    standard   22.87660 5 11.206537 Preprocessor1_Model40
# 41 41        rmse    standard   22.80352 5 11.232839 Preprocessor1_Model41
# 42 42        rmse    standard   22.74015 5 11.220416 Preprocessor1_Model42
# 43 43        rmse    standard   22.66322 5 11.246237 Preprocessor1_Model43
# 44 44        rmse    standard   22.58545 5 11.231208 Preprocessor1_Model44
# 45 45        rmse    standard   22.57303 5 11.212436 Preprocessor1_Model45
# 46 46        rmse    standard   22.53796 5 11.222031 Preprocessor1_Model46
# 47 47        rmse    standard   22.48066 5 11.242490 Preprocessor1_Model47
# 48 48        rmse    standard   22.55685 5 11.232349 Preprocessor1_Model48
# 49 49        rmse    standard   22.52407 5 11.209115 Preprocessor1_Model49
# 50 50        rmse    standard   22.56545 5 11.172834 Preprocessor1_Model50
# plot without title

# %%
# Choose the neighbor with the lowest rmse value.
players_rmse_min <- players_results |>
                        filter(mean == min(mean))
players_rmse_min
# Out:
#   neighbors .metric .estimator mean     n std_err .config
# 1 24        rmse    standard   22.30877 5 11.384  Preprocessor1_Model24

# %%
# Calculate the rmse of the neighbors on the testing data set.

players_spec_11 <- nearest_neighbor(weight_func = "rectangular", neighbors = 11) |>
                        set_engine("kknn") |>
                        set_mode("regression")

players_recipe <- recipe(played_hours ~ age, data = players) |>
                        step_scale(all_predictors()) |>
                        step_center(all_predictors())

players_workflow_11 <- workflow() |>
                            add_recipe(players_recipe) |>
                            add_model(players_spec_11) |>
                            fit(players_test)

players_summary_test <- players_workflow_11 |>
                            predict(players_test) |>
                            bind_cols(players_test) |>
                            metrics(truth = played_hours, estimate = .pred) |>
                            filter(.metric == "rmse")
players_summary_test


# Results mean that the RMSPE is off by 49.77865 years...
# Out:
#   .metric .estimator .estimate
# 1 rmse    standard   49.77865

# %%
# Plot our final predictor results.

players_prediction_grid <- tibble(age = seq(from = players |> select(age) |> min(), 
                                            to = players |> select(age) |> max(), 
                                            by = 1))

players_predictions <- players_workflow_11 |>
                            predict(players_prediction_grid) |>
                            bind_cols(players_prediction_grid)

players_final_plot <- players |>
                        ggplot(aes(x = age, y = played_hours)) +
                            geom_point() +
                            geom_line(data = players_predictions, 
                                      mapping = aes(x = age, y = .pred), 
                                      color = "steelblue", 
                                      linewidth = 1) +
                            xlab("Age of Player") +
                            ylab("Total Hours Played") +
                            theme(text = element_text(size = 12))
players_final_plot
# Out:
# plot without title
